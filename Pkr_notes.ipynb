# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Pkr_Notes.v3-abdul.yolov9
# Out:
# /content/drive/MyDrive/Pkr_Notes.v3-abdul.yolov9

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=10 imgsz=640 plots=True conf=0.01
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 121MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=10 imgsz=640 plots=True batch=32 workers=16 conf=0.002
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=10 imgsz=640 plots=True batch=10 workers=5 conf=0.002 #lr0=0.02, lrf=0.02
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=10 imgsz=640 plots=True batch=64 workers=4 conf=0.002 mask_ratio=2
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=8 imgsz=640 plots=True batch=19 workers=9 conf=0.002 mask_ratio=6 patience=25
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train2/
# Out:
# args.yaml					     results.csv	    val_batch1_labels.jpg
# confusion_matrix.png				     results.png	    val_batch1_pred.jpg
# events.out.tfevents.1720468268.6a0ef28876c5.12034.0  train_batch0.jpg	    val_batch2_labels.jpg
# F1_curve.png					     train_batch1.jpg	    val_batch2_pred.jpg
# P_curve.png					     train_batch2.jpg	    weights
# PR_curve.png					     val_batch0_labels.jpg
# R_curve.png					     val_batch0_pred.jpg

# %%
Image(filename='runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train3/results.png', width=600)

# %%
Image(filename='runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# 2024-07-08 20:33:31.069838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 20:33:31.069902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 20:33:31.071427: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-08 20:33:31.079826: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source='/content/drive/MyDrive/Pkr_Notes.v3-abdul.yolov9/test/images' save=True
# Out:
# 2024-07-08 20:34:30.669189: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 20:34:30.669239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 20:34:30.670473: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-08 20:34:30.677320: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
